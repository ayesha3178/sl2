# %%
import seaborn as sns

import matplotlib.pyplot as plt

import numpy as np

sns.set_style('whitegrid')

titanic=load_dataset('titanic')

# Create a histogram of the fare column

plt.figure(figsize=(10, 6))

sns.histplot(titanic['fare'], bins=30, kde=False, color='blue')



# Add labels and title

plt.xlabel('Fare')

plt.ylabel('Number of Passengers')

plt.title('Distribution of Ticket Prices (Fare) for Titanic Passengers')



# Show the plot

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 9
#       5 import numpy as np
#       7 sns.set_style('whitegrid')
# ----> 9 titanic=load_dataset('titanic')
#      11 # Create a histogram of the fare column
#      13 plt.figure(figsize=(10, 6))
#
# NameError: name 'load_dataset' is not defined
